# %% [markdown]
# <a href="https://colab.research.google.com/github/KarenDahianaGomezGomez/Entrega-Final---Algoritmia-y-Programacion/blob/main/Proyecto_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROYECTO FINAL - ALGORITMIA Y PROGRAMACIÓN**

# %% [markdown]
# ##**Karen Dahiana Gómez Gómez - C.C 1040873146**

# %% [markdown]
# ##Registro log

# %%
import pandas as pd
import os
from datetime import datetime
import time
import platform
import getpass

# Inicializamos el archivo de log
log_file = "event_log.txt"

# Función para registrar eventos en el log
def registrar_evento(evento):
    with open(log_file, "a") as log:
        ahora = datetime.now()
        timestamp = ahora.strftime("%Y-%m-%d %H:%M:%S.%f")[:-3]
        log.write(f"{timestamp}\t{evento}\n")

# Registrar encabezado del log
usuario = getpass.getuser()
sistema = platform.system()
plataforma = platform.platform()
procesador = platform.processor()

with open(log_file, "w") as log:
    log.write(f"Usuario: {usuario}\n")
    log.write(f"Sistema operativo: {sistema}\n")
    log.write(f"Plataforma: {plataforma}\n")
    log.write(f"Procesador: {procesador}\n")
    log.write("Fecha y hora\t\t\tEvento\n")

cantidad_procedimientos = 0

# %% [markdown]
# ##Generación de estudiantes con su nombre, semestre y datos personales

# %%
import csv
import random
import requests

# GENERACIÓN DE LOS 1000 NOMBRES DE LOS ESTUDIANTES

start_time = time.time()
def read_csv_from_url(url):
    response = requests.get(url)
    lines = response.text.split('\n')
    data = [row[0] for row in csv.reader(lines) if row]  # Agregamos un chequeo para evitar líneas vacías
    return data

# Leemos los archivos CSV de nombres y apellidos
nombres = read_csv_from_url('https://raw.githubusercontent.com/KarenDahianaGomezGomez/Entrega-Final---Algoritmia-y-Programacion/main/nombres.csv')
apellidos = read_csv_from_url('https://raw.githubusercontent.com/KarenDahianaGomezGomez/Entrega-Final---Algoritmia-y-Programacion/main/apellidos.csv')

end_time = time.time()
registrar_evento(f"Lectura de los archivos CSV de nombres y apellidos:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1

# Creamos todas las combinaciones posibles de nombres y apellidos
start_time = time.time()
combinaciones = [(nombre, apellido1, apellido2) for nombre in nombres for apellido1 in apellidos for apellido2 in apellidos]

# Mezclamos aleatoriamente las combinaciones
random.shuffle(combinaciones)

# Seleccionamos las primeras 1000 combinaciones únicas
nombres_completos = set()
nombres_finales = []
for nombre, apellido1, apellido2 in combinaciones:
    nombre_completo = f"{nombre} {apellido1} {apellido2}"
    if nombre_completo not in nombres_completos:
        nombres_completos.add(nombre_completo)
        nombres_finales.append(nombre_completo)
    if len(nombres_finales) == 1000:
        break

end_time = time.time()
registrar_evento(f" Creacion de las primeras 1000 combinaciones únicas:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1


# REPARTICIÓN DE LOS ESTUDIANTES POR SEMESTRE

import random

# Lista de 1000 nombres generados
# La lista ya está generada como nombres_finales
# nombres_finales = [...]

# Proporciones por semestre
start_time = time.time()
semestre_proporciones = [0.14, 0.13, 0.12, 0.11, 0.10, 0.10, 0.09, 0.08, 0.07, 0.06]

# Calculamos el número de estudiantes por semestre
semestre_cupos = [int(1000 * p) for p in semestre_proporciones]

# Asignamos estudiantes a semestres
estudiantes_por_semestre = {i + 1: [] for i in range(10)}

random.shuffle(nombres_finales)

indice = 0
for semestre, cupo in enumerate(semestre_cupos, start=1):
    for _ in range(cupo):
        estudiante = {
            'nombre': nombres_finales[indice],
            'semestre': semestre
        }
        estudiantes_por_semestre[semestre].append(estudiante)
        indice += 1

end_time = time.time()
registrar_evento(f"Asignacion de los estudiantes a semestres:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1




# CREACIÓN DE LOS DATOS PERSONALES DE LOS ESTUDIANTES
start_time = time.time()
import random
import string

# Proporciones por semestre
semestre_proporciones = [0.14, 0.13, 0.12, 0.11, 0.10, 0.10, 0.09, 0.08, 0.07, 0.06]

# Calculamos el número de estudiantes por semestre
semestre_cupos = [int(1000 * p) for p in semestre_proporciones]

# Asignamos estudiantes a semestres
estudiantes_por_semestre = {i + 1: [] for i in range(10)}

random.shuffle(nombres_finales)

# Función para generar un documento de identidad único
def generar_documento():
    return ''.join(random.choices(string.digits, k=10))

# Función para generar un correo electrónico único
def generar_correo(nombre, indice):
    base_correo = nombre.lower().replace(' ', '.') + f"{indice:04d}"
    return base_correo + "@udea.edu.co"

# Seccionales disponibles
seccionales = [
    "Seccional Urabá", "Sede Norte", "Ciudad Universitaria", "Seccional Occidente",
    "Seccional Suroeste", "Seccional Bajo Cauca", "Sede Distrito Minero",
    "Sede Nordeste", "Seccional Magdalena Medio", "Seccional Oriente", "Sede Sonsón"
]

# Conjuntos para verificar unicidad
documentos_unicos = set()
correos_unicos = set()

indice = 0
for semestre, cupo in enumerate(semestre_cupos, start=1):
    for _ in range(cupo):
        nombre = nombres_finales[indice]
        documento = generar_documento()
        while documento in documentos_unicos:
            documento = generar_documento()
        documentos_unicos.add(documento)

        correo = generar_correo(nombre, indice)
        while correo in correos_unicos:
            correo = generar_correo(nombre, indice + random.randint(1, 1000))
        correos_unicos.add(correo)

        seccional = random.choice(seccionales)

        estudiante = {
            'nombre': nombre,
            'semestre': semestre,
            'documento': documento,
            'correo': correo,
            'seccional': seccional
        }
        estudiantes_por_semestre[semestre].append(estudiante)
        indice += 1

end_time = time.time()
registrar_evento(f"Creacion de los datos personales de los estudiantes:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1

# Imprimimos los primeros 10 estudiantes de cada semestre como ejemplo
for semestre, estudiantes in estudiantes_por_semestre.items():
    print(f"Semestre {semestre}:")
    for estudiante in estudiantes[:10]:
        print(estudiante)


# CREACIÓN DEL ARCHIVO PLANO CON EL LISTADO DE ESTUDIANTES, SEMESTRES Y SUS DATOS PERSONALES

import csv

# Función para escribir los datos de los estudiantes en un archivo CSV
start_time = time.time()
def escribir_estudiantes_csv(estudiantes_por_semestre, filename):
    with open(filename, 'w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=['nombre', 'semestre', 'documento', 'correo', 'seccional'])
        writer.writeheader()
        for semestre, estudiantes in estudiantes_por_semestre.items():
            for estudiante in estudiantes:
                writer.writerow(estudiante)

# Llamada a la función para escribir los datos en un archivo CSV
escribir_estudiantes_csv(estudiantes_por_semestre, 'estudiantes.csv')

end_time = time.time()
registrar_evento(f"Creacion del archivo plano con los datos de los estudiantes:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1
# Out:
# Semestre 1:
# {'nombre': ' Juan  Vidal  León', 'semestre': 1, 'documento': '7253271143', 'correo': '.juan..vidal..león0000@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Ana  Hidalgo  Cervantes', 'semestre': 1, 'documento': '3520395133', 'correo': '.ana..hidalgo..cervantes0001@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Juliana  Nieto  Gil', 'semestre': 1, 'documento': '3120285648', 'correo': '.juliana..nieto..gil0002@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Ricardo  Cervantes  Soto', 'semestre': 1, 'documento': '9439634667', 'correo': '.ricardo..cervantes..soto0003@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Antonia  Robles  Ortega', 'semestre': 1, 'documento': '0783060486', 'correo': '.antonia..robles..ortega0004@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Juan José  Molina  Vidal', 'semestre': 1, 'documento': '0666998421', 'correo': '.juan.josé..molina..vidal0005@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Cristóbal  Gil  Reyes', 'semestre': 1, 'documento': '8760068374', 'correo': '.cristóbal..gil..reyes0006@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Natalia  Cruz  Peralta', 'semestre': 1, 'documento': '9883586908', 'correo': '.natalia..cruz..peralta0007@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Mateo  Pastor  Robles', 'semestre': 1, 'documento': '4958339554', 'correo': '.mateo..pastor..robles0008@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Andrés  Mesa  Pascual', 'semestre': 1, 'documento': '2520802921', 'correo': '.andrés..mesa..pascual0009@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# Semestre 2:
# {'nombre': ' Tomás  Molina  Cordero', 'semestre': 2, 'documento': '1977227696', 'correo': '.tomás..molina..cordero0140@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Isabel  Cervantes  Abad', 'semestre': 2, 'documento': '2955642505', 'correo': '.isabel..cervantes..abad0141@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Natalia  Peralta  Álvarez', 'semestre': 2, 'documento': '2267514234', 'correo': '.natalia..peralta..álvarez0142@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Andrea  Blanco  Ochoa', 'semestre': 2, 'documento': '0631126099', 'correo': '.andrea..blanco..ochoa0143@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# {'nombre': ' Tomás  Abad  Carretero', 'semestre': 2, 'documento': '3772829167', 'correo': '.tomás..abad..carretero0144@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Valeria  Oliva  Linares', 'semestre': 2, 'documento': '4946328096', 'correo': '.valeria..oliva..linares0145@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' David  Soto \ufeffApellidos', 'semestre': 2, 'documento': '0981036851', 'correo': '.david..soto.\ufeffapellidos0146@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Andrea  Gil  Varela', 'semestre': 2, 'documento': '6672564223', 'correo': '.andrea..gil..varela0147@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Sebastián  Ruiz  Casado', 'semestre': 2, 'documento': '3033229822', 'correo': '.sebastián..ruiz..casado0148@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# {'nombre': ' Francisco  Romero  Ruiz', 'semestre': 2, 'documento': '8935993521', 'correo': '.francisco..romero..ruiz0149@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# Semestre 3:
# {'nombre': ' Andrés  Ramos  León', 'semestre': 3, 'documento': '5120641083', 'correo': '.andrés..ramos..león0270@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Catalina  Navarro  López', 'semestre': 3, 'documento': '9440627333', 'correo': '.catalina..navarro..lópez0271@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Daniela  Morales  González', 'semestre': 3, 'documento': '5633887162', 'correo': '.daniela..morales..gonzález0272@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Alexander  Alonso  Linares', 'semestre': 3, 'documento': '9208060680', 'correo': '.alexander..alonso..linares0273@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Leonardo  Romero  Muñoz', 'semestre': 3, 'documento': '0402710741', 'correo': '.leonardo..romero..muñoz0274@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Juan José  Gómez  Rivas', 'semestre': 3, 'documento': '1149050293', 'correo': '.juan.josé..gómez..rivas0275@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Antonia  Alonso  Alonso', 'semestre': 3, 'documento': '3195777512', 'correo': '.antonia..alonso..alonso0276@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' María José  Rivas  Muñoz', 'semestre': 3, 'documento': '5417110753', 'correo': '.maría.josé..rivas..muñoz0277@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Daniel  Marín  Varela', 'semestre': 3, 'documento': '1729610847', 'correo': '.daniel..marín..varela0278@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Cristóbal  Vega  Linares', 'semestre': 3, 'documento': '9399761745', 'correo': '.cristóbal..vega..linares0279@udea.edu.co', 'seccional': 'Sede Norte'}
# Semestre 4:
# {'nombre': ' Isabella  Reyes  Torres', 'semestre': 4, 'documento': '9109455336', 'correo': '.isabella..reyes..torres0390@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Simón  Bravo  Serrano', 'semestre': 4, 'documento': '9769987313', 'correo': '.simón..bravo..serrano0391@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Diego  Ochoa  Prieto', 'semestre': 4, 'documento': '1045654171', 'correo': '.diego..ochoa..prieto0392@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Leonardo  Varela  León', 'semestre': 4, 'documento': '2335113494', 'correo': '.leonardo..varela..león0393@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Andrea  Alonso  Ortiz', 'semestre': 4, 'documento': '6426931829', 'correo': '.andrea..alonso..ortiz0394@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Ángel  Cabrera  Prieto', 'semestre': 4, 'documento': '2243462265', 'correo': '.ángel..cabrera..prieto0395@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Juan  Reyes  Linares', 'semestre': 4, 'documento': '5198472691', 'correo': '.juan..reyes..linares0396@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Ana  Correa  Gil', 'semestre': 4, 'documento': '8285535999', 'correo': '.ana..correa..gil0397@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Juan José  Gómez  Correa', 'semestre': 4, 'documento': '8455222733', 'correo': '.juan.josé..gómez..correa0398@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Isabella  León  Cervantes', 'semestre': 4, 'documento': '0866785768', 'correo': '.isabella..león..cervantes0399@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# Semestre 5:
# {'nombre': ' Mateo  González  León', 'semestre': 5, 'documento': '7728922780', 'correo': '.mateo..gonzález..león0500@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Valentina  Cordero  Amaya', 'semestre': 5, 'documento': '8376293326', 'correo': '.valentina..cordero..amaya0501@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Emily  Álvarez  Domínguez', 'semestre': 5, 'documento': '9358508694', 'correo': '.emily..álvarez..domínguez0502@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Fernanda  Medina  Vázquez', 'semestre': 5, 'documento': '0392491357', 'correo': '.fernanda..medina..vázquez0503@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Natalia  Ferrer  Martínez', 'semestre': 5, 'documento': '9577245584', 'correo': '.natalia..ferrer..martínez0504@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Esteban \ufeffApellidos  Delgado', 'semestre': 5, 'documento': '1398576152', 'correo': '.esteban.\ufeffapellidos..delgado0505@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Emma  Linares  Rivas', 'semestre': 5, 'documento': '5714778278', 'correo': '.emma..linares..rivas0506@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Christian  Guerrero  Molina', 'semestre': 5, 'documento': '3830085091', 'correo': '.christian..guerrero..molina0507@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Samuel  Serrano  Hidalgo', 'semestre': 5, 'documento': '4022283612', 'correo': '.samuel..serrano..hidalgo0508@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Samantha  González  Vázquez', 'semestre': 5, 'documento': '8054178320', 'correo': '.samantha..gonzález..vázquez0509@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# Semestre 6:
# {'nombre': ' Andrea  León  Domínguez', 'semestre': 6, 'documento': '4216985903', 'correo': '.andrea..león..domínguez0600@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Manuel  Cruz  Abad', 'semestre': 6, 'documento': '7032107523', 'correo': '.manuel..cruz..abad0601@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Nicolás  Linares  Ramos', 'semestre': 6, 'documento': '9054904831', 'correo': '.nicolás..linares..ramos0602@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Sofia  Torres  Soler', 'semestre': 6, 'documento': '7131909125', 'correo': '.sofia..torres..soler0603@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' José  Cortés  Rubio', 'semestre': 6, 'documento': '0807849616', 'correo': '.josé..cortés..rubio0604@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Leonardo  López  Mesa', 'semestre': 6, 'documento': '8353598585', 'correo': '.leonardo..lópez..mesa0605@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Emma  Ochoa  Luque', 'semestre': 6, 'documento': '0261003372', 'correo': '.emma..ochoa..luque0606@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Simón  Vargas  Ramos', 'semestre': 6, 'documento': '0037065616', 'correo': '.simón..vargas..ramos0607@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Diego  Pérez  Domínguez', 'semestre': 6, 'documento': '4249486331', 'correo': '.diego..pérez..domínguez0608@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Gabriela  Miranda  Ochoa', 'semestre': 6, 'documento': '5303294604', 'correo': '.gabriela..miranda..ochoa0609@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# Semestre 7:
# {'nombre': ' Mateo  Domínguez  Álvarez', 'semestre': 7, 'documento': '9788176865', 'correo': '.mateo..domínguez..álvarez0700@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Valeria  Pascual  Medina', 'semestre': 7, 'documento': '3472844292', 'correo': '.valeria..pascual..medina0701@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Juan Pablo  Molina  Carmona', 'semestre': 7, 'documento': '4761735683', 'correo': '.juan.pablo..molina..carmona0702@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Matías  Carmona  García', 'semestre': 7, 'documento': '6173211483', 'correo': '.matías..carmona..garcía0703@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Camila  González  Domínguez', 'semestre': 7, 'documento': '2347196012', 'correo': '.camila..gonzález..domínguez0704@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Juan Pablo  Santana  Muñoz', 'semestre': 7, 'documento': '4433111337', 'correo': '.juan.pablo..santana..muñoz0705@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Jimena  Moya  García', 'semestre': 7, 'documento': '6883729618', 'correo': '.jimena..moya..garcía0706@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Esteban  Peralta  Ríos', 'semestre': 7, 'documento': '9463374244', 'correo': '.esteban..peralta..ríos0707@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Valeria  Ramírez  Molina', 'semestre': 7, 'documento': '0569252257', 'correo': '.valeria..ramírez..molina0708@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Isabella  Miranda  Amaya', 'semestre': 7, 'documento': '2758806803', 'correo': '.isabella..miranda..amaya0709@udea.edu.co', 'seccional': 'Sede Norte'}
# Semestre 8:
# {'nombre': ' Tomás  Gallego  Calvo', 'semestre': 8, 'documento': '0484674379', 'correo': '.tomás..gallego..calvo0790@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Ana  Oliva  Linares', 'semestre': 8, 'documento': '3293235424', 'correo': '.ana..oliva..linares0791@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Daniela  Medina  Medina', 'semestre': 8, 'documento': '3400942991', 'correo': '.daniela..medina..medina0792@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Antonia  García  Blanco', 'semestre': 8, 'documento': '6511356146', 'correo': '.antonia..garcía..blanco0793@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' María  Blanco  Rivas', 'semestre': 8, 'documento': '8244568279', 'correo': '.maría..blanco..rivas0794@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Sebastián  Delgado  Lucas', 'semestre': 8, 'documento': '3111294865', 'correo': '.sebastián..delgado..lucas0795@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Andrés  González  Cordero', 'semestre': 8, 'documento': '1924382242', 'correo': '.andrés..gonzález..cordero0796@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# {'nombre': ' Natalia  Cortés  Suárez', 'semestre': 8, 'documento': '4766524711', 'correo': '.natalia..cortés..suárez0797@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': '\ufeffNombre \ufeffApellidos  Gallego', 'semestre': 8, 'documento': '0956203473', 'correo': '\ufeffnombre.\ufeffapellidos..gallego0798@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# {'nombre': ' Antonia  Hidalgo  Prieto', 'semestre': 8, 'documento': '9155068752', 'correo': '.antonia..hidalgo..prieto0799@udea.edu.co', 'seccional': 'Seccional Occidente'}
# Semestre 9:
# {'nombre': ' Agustín  Bravo  Molina', 'semestre': 9, 'documento': '8539488665', 'correo': '.agustín..bravo..molina0870@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' María  Blanco  Nieto', 'semestre': 9, 'documento': '8198804606', 'correo': '.maría..blanco..nieto0871@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Juan Pablo  Ruiz  Abad', 'semestre': 9, 'documento': '1292565914', 'correo': '.juan.pablo..ruiz..abad0872@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Elena  Linares  Gallego', 'semestre': 9, 'documento': '6483812950', 'correo': '.elena..linares..gallego0873@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Simón  Medina  López', 'semestre': 9, 'documento': '4275115472', 'correo': '.simón..medina..lópez0874@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' María José  Casado  Herrero', 'semestre': 9, 'documento': '5058836511', 'correo': '.maría.josé..casado..herrero0875@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Sofia  Domínguez  Prieto', 'semestre': 9, 'documento': '6271190664', 'correo': '.sofia..domínguez..prieto0876@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Natalia  Molina  Domínguez', 'semestre': 9, 'documento': '0359573149', 'correo': '.natalia..molina..domínguez0877@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Tomás  Molina  Carretero', 'semestre': 9, 'documento': '2726644634', 'correo': '.tomás..molina..carretero0878@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Emma  Vargas  Mesa', 'semestre': 9, 'documento': '7204998884', 'correo': '.emma..vargas..mesa0879@udea.edu.co', 'seccional': 'Sede Norte'}
# Semestre 10:
# {'nombre': ' Pablo  Díaz  Cabello', 'semestre': 10, 'documento': '0042814864', 'correo': '.pablo..díaz..cabello0940@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Valentina  Herrera  Morales', 'semestre': 10, 'documento': '3689855987', 'correo': '.valentina..herrera..morales0941@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Gabriela  Varela  Peralta', 'semestre': 10, 'documento': '3762452752', 'correo': '.gabriela..varela..peralta0942@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Nicolás  Abad  Cervantes', 'semestre': 10, 'documento': '0239605551', 'correo': '.nicolás..abad..cervantes0943@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' David  Fernández  Fernández', 'semestre': 10, 'documento': '7097279164', 'correo': '.david..fernández..fernández0944@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Sofía \ufeffApellidos  Amaya', 'semestre': 10, 'documento': '8355647985', 'correo': '.sofía.\ufeffapellidos..amaya0945@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Juliana  Herrero  Molina', 'semestre': 10, 'documento': '2047808665', 'correo': '.juliana..herrero..molina0946@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Daniela  Vidal  Cabrera', 'semestre': 10, 'documento': '8266957319', 'correo': '.daniela..vidal..cabrera0947@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Juan  Ortega  Ochoa', 'semestre': 10, 'documento': '2288561040', 'correo': '.juan..ortega..ochoa0948@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Valentina  Calvo  Suárez', 'semestre': 10, 'documento': '3685933695', 'correo': '.valentina..calvo..suárez0949@udea.edu.co', 'seccional': 'Sede Distrito Minero'}

# %% [markdown]
# ##Creación de la carpeta "Entrega Final"

# %%
import os
start_time = time.time()
# Función para crear una carpeta si no existe
def crear_carpeta_si_no_existe(ruta):
    if not os.path.exists(ruta):
        os.makedirs(ruta)

# Crear carpeta "Entrega Final" en el entorno de Colab
entrega_final_path = 'Entrega Final'
crear_carpeta_si_no_existe(entrega_final_path)

end_time = time.time()
registrar_evento(f"Creacion carpeta Entrega Final en el entorno de Colab:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1

# %% [markdown]
# ###Creación de las carpetas de los semestres

# %%
import os
import pandas as pd
from datetime import datetime

# Crear carpeta "Entrega Final"
entrega_final_path = 'Entrega Final'
if not os.path.exists(entrega_final_path):
    os.makedirs(entrega_final_path)

# Materias por semestre
materias_por_semestre = {
    1: [
        {"nombre": "Álgebra y Trigonometría", "creditos": 3},
        {"nombre": "Cálculo Diferencial", "creditos": 3},
        {"nombre": "Geometría Vectorial y Analítica", "creditos": 3},
        {"nombre": "Vivamos la Universidad", "creditos": 3},
        {"nombre": "Inglés I", "creditos": 1},
        {"nombre": "Lectoescritura", "creditos": 1},
        {"nombre": "Introducción a la Ingeniería Industrial", "creditos": 1},
    ],
    2: [
        {"nombre": "Álgebra Lineal", "creditos": 3},
        {"nombre": "Cálculo Integral", "creditos": 3},
        {"nombre": "Descubriendo la Física", "creditos": 3},
        {"nombre": "Gestión de las Organizaciones", "creditos": 3},
        {"nombre": "Inglés II", "creditos": 1},
        {"nombre": "Habilidades Gerenciales", "creditos": 3},
    ],
    3: [
        {"nombre": "Algoritmia y Programación", "creditos": 3},
        {"nombre": "Física Mecánica", "creditos": 3},
        {"nombre": "Gestión Contable", "creditos": 3},
        {"nombre": "Probabilidad e Inferencia Estadística", "creditos": 3},
        {"nombre": "Inglés III", "creditos": 1},
        {"nombre": "Teoría General de Sistemas", "creditos": 3},
    ],
    4: [
        {"nombre": "Diseño de Experimentos y Análisis de Regresión", "creditos": 3},
        {"nombre": "Electiva en Física", "creditos": 3},
        {"nombre": "Gestión de Métodos y Tiempos", "creditos": 4},
        {"nombre": "Ingeniería Económica", "creditos": 3},
        {"nombre": "Inglés IV", "creditos": 1},
        {"nombre": "Optimización", "creditos": 3},
    ],
    5: [
        {"nombre": "Dinámica de Sistemas", "creditos": 3},
        {"nombre": "Formación ciudadana y Constitucional", "creditos": 1},
        {"nombre": "Gestión Financiera", "creditos": 3},
        {"nombre": "Gestión por Procesos", "creditos": 3},
        {"nombre": "Inglés V", "creditos": 1},
        {"nombre": "Laboratorio Integrado de Física", "creditos": 1},
        {"nombre": "Muestreo y Series de Tiempo", "creditos": 3},
        {"nombre": "Procesos Estocásticos y Análisis de Decisión", "creditos": 3},
    ],
    6: [
        {"nombre": "Electiva en Humanidades I", "creditos": 3},
        {"nombre": "Formulación de Proyectos de Investigación", "creditos": 3},
        {"nombre": "Gestión Tecnológica", "creditos": 3},
        {"nombre": "Inglés VI", "creditos": 1},
        {"nombre": "Legislación", "creditos": 3},
        {"nombre": "Normalización y Control de la Calidad", "creditos": 3},
        {"nombre": "Simulación Discreta", "creditos": 3},
    ],
    7: [
        {"nombre": "Diseño de Sistemas Productivos", "creditos": 3},
        {"nombre": "Electiva Complementaria I", "creditos": 3},
        {"nombre": "Electiva en Humanidades II", "creditos": 3},
        {"nombre": "Emprendimiento", "creditos": 2},
        {"nombre": "Énfasis Profesional I", "creditos": 3},
        {"nombre": "Formulación y Evaluación de Proyectos de Inversión", "creditos": 3},
    ],
    8: [
        {"nombre": "Administración de la Producción y del Servicio", "creditos": 3},
        {"nombre": "Electiva Complementaria II", "creditos": 3},
        {"nombre": "Electiva en Humanidades III", "creditos": 3},
        {"nombre": "Énfasis Profesional II", "creditos": 3},
        {"nombre": "Gestión de Proyectos", "creditos": 3},
    ],
    9: [
        {"nombre": "Electiva Complementaria III", "creditos": 3},
        {"nombre": "Electiva en Humanidades IV", "creditos": 3},
        {"nombre": "Gestión de la Cadena de Abastecimiento", "creditos": 3},
        {"nombre": "Énfasis Profesional III", "creditos": 3},
        {"nombre": "Ingeniería del Mejoramiento Continuo", "creditos": 3},
    ],
    10: [
        {"nombre": "Práctica Profesional", "creditos": 12},
    ],
}

# Reglas de conversión de créditos a HTD y HTI
creditos_a_htd = {
    12: 288,
    4: 96,
    3: 64,
    2: 32,
    1: 16
}
creditos_a_hti = {
    12: 360,
    4: 120,
    3: 80,
    2: 64,
    1: 32
}

# Capacidad máxima de los grupos por semestre
capacidad_grupos = {
    1: 30,
    2: 30,
    3: 30,
    4: 25,
    5: 25,
    6: 25,
    7: 20,
    8: 20,
    9: 20,
    10: 10
}

# Función para generar un código de asignatura
start_time = time.time()
def generar_codigo_asignatura(nombre, semestre, creditos, consecutivo):
    nombre_reducido = ''.join([palabra[0] for palabra in nombre.split()][:3])
    nombre_reducido = (nombre_reducido + nombre[:3]).upper()[:3]
    codigo = f"{nombre_reducido}{semestre}{creditos}{consecutivo}"
    return codigo

end_time = time.time()
registrar_evento(f"generacion de un código de asignatura:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1

# Leer datos de estudiantes desde el archivo estudiantes.csv
estudiantes_df = pd.read_csv('estudiantes.csv')

# Crear carpetas de semestre del 1 al 10
# Crear carpetas de semestre del 1 al 10
start_time = time.time()
for semestre in range(1, 11):
    semestre_path = os.path.join(entrega_final_path, f'semestre {semestre}')
    if not os.path.exists(semestre_path):
        os.makedirs(semestre_path)

    if semestre in materias_por_semestre:
        materias_semestre = materias_por_semestre[semestre]
        codigos_asignaturas_semestre = {}
        consecutivos = {}
        asignaturas_info = []

        for asignatura in materias_semestre:
            nombre = asignatura["nombre"]
            creditos = asignatura["creditos"]
            htd = creditos_a_htd[creditos]
            hti = creditos_a_hti[creditos]

            if nombre not in consecutivos:
                consecutivos[nombre] = 1
            else:
                consecutivos[nombre] += 1

            codigo = generar_codigo_asignatura(nombre, semestre, creditos, consecutivos[nombre])
            codigos_asignaturas_semestre[nombre] = codigo

            asignaturas_info.append({
                "nombre": nombre,
                "codigo": codigo,
                "creditos": creditos,
                "htd": htd,
                "hti": hti
            })

        # Seleccionar estudiantes para el semestre actual
        estudiantes_semestre = estudiantes_df[estudiantes_df['semestre'] == semestre]
        estudiantes_semestre = estudiantes_semestre.sample(frac=1).reset_index(drop=True)  # Mezclar estudiantes

        # Crear carpetas de asignaturas y archivos dentro de cada semestre
        for asignatura in asignaturas_info:
            asignatura_path = os.path.join(semestre_path, asignatura["nombre"].replace(" ", "_"))
            if not os.path.exists(asignatura_path):
                os.makedirs(asignatura_path)

            # Dividir estudiantes en grupos según la capacidad máxima del semestre
            capacidad = capacidad_grupos[semestre]
            grupos = [estudiantes_semestre[i:i + capacidad] for i in range(0, len(estudiantes_semestre), capacidad)]

            for idx, grupo in enumerate(grupos):
                cantidad_estudiantes = len(grupo)
                codigo_grupo = idx + 1
                nombre_archivo = f"{asignatura['codigo']}-{asignatura['nombre'].replace(' ', '')}-{cantidad_estudiantes}-G{codigo_grupo}"

                df = grupo.copy()
                df['Código Asignatura'] = asignatura['codigo']
                df['Horas de trabajo docente (HTD)'] = asignatura['htd']
                df['Horas de trabajo independiente (HTI)'] = asignatura['hti']
                df['Número total de estudiantes (NTE)'] = cantidad_estudiantes
                df['Código del curso (CC)'] = f"{asignatura['codigo']}-G{codigo_grupo}"
                df['Total de cursos asignados (TCA)'] = len(grupos)
                df['Fecha de creación (FC)'] = datetime.now().strftime("%Y/%m/%d")
                df['Créditos de la asignatura'] = asignatura['creditos']

                ruta_excel = os.path.join(asignatura_path, f"{nombre_archivo}.xlsx")
                start_time = time.time()
                with pd.ExcelWriter(ruta_excel) as writer:
                     df.to_excel(writer, sheet_name="Estudiantes", index=False)
                end_time = time.time()
                registrar_evento(f"Guardado archivo Excel:  en {end_time - start_time:.3f} segundos")
                cantidad_procedimientos += 1

                ruta_csv = os.path.join(asignatura_path, f"{nombre_archivo}.csv")
                start_time = time.time()
                df.to_csv(ruta_csv, index=False)
                end_time = time.time()
                registrar_evento(f"Guardado archivo CSV:  en {end_time - start_time:.3f} segundos")
                cantidad_procedimientos += 1

# Registrar la cantidad total de procedimientos realizados
registrar_evento(f"Cantidad total de procedimientos realizados: {cantidad_procedimientos}")

print("Operaciones realizadas y eventos registrados exitosamente.")
# Out:
# Operaciones realizadas y eventos registrados exitosamente.
