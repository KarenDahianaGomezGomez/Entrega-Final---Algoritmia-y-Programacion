# %% [markdown]
# <a href="https://colab.research.google.com/github/KarenDahianaGomezGomez/Entrega-Final---Algoritmia-y-Programacion/blob/main/Proyecto_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROYECTO FINAL - ALGORITMIA Y PROGRAMACIÓN**

# %% [markdown]
# ##**Karen Dahiana Gómez Gómez - C.C 1040873146**

# %% [markdown]
# ##Registro log

# %%
import pandas as pd
import os
from datetime import datetime
import time
import platform
import getpass

# Inicializamos el archivo de log
log_file = "event_log.txt"

# Función para registrar eventos en el log
def registrar_evento(evento):
    with open(log_file, "a") as log:
        ahora = datetime.now()
        timestamp = ahora.strftime("%Y-%m-%d %H:%M:%S.%f")[:-3]
        log.write(f"{timestamp}\t{evento}\n")

# Registrar encabezado del log
usuario = getpass.getuser()
sistema = platform.system()
plataforma = platform.platform()
procesador = platform.processor()

with open(log_file, "w") as log:
    log.write(f"Usuario: {usuario}\n")
    log.write(f"Sistema operativo: {sistema}\n")
    log.write(f"Plataforma: {plataforma}\n")
    log.write(f"Procesador: {procesador}\n")
    log.write("Fecha y hora\t\t\tEvento\n")

cantidad_procedimientos = 0

# %% [markdown]
# ##Generación de estudiantes con su nombre, semestre y datos personales

# %%
import csv
import random

# GENERACIÓN DE LOS 1000 NOMBRES DE LOS ESTUDIANTES

start_time = time.time()
def read_csv_from_url(url):
    response = requests.get(url)
    lines = response.text.split('\n')
    data = [row[0] for row in csv.reader(lines) if row]  # Agregamos un chequeo para evitar líneas vacías
    return data

# Leemos los archivos CSV de nombres y apellidos
nombres = read_csv_from_url('https://raw.githubusercontent.com/KarenDahianaGomezGomez/Entrega-Final---Algoritmia-y-Programacion/main/nombres.csv')
apellidos = read_csv_from_url('https://raw.githubusercontent.com/KarenDahianaGomezGomez/Entrega-Final---Algoritmia-y-Programacion/main/apellidos.csv')

end_time = time.time()
registrar_evento(f"Lectura de los archivos CSV de nombres y apellidos:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1

# Creamos todas las combinaciones posibles de nombres y apellidos
start_time = time.time()
combinaciones = [(nombre, apellido1, apellido2) for nombre in nombres for apellido1 in apellidos for apellido2 in apellidos]

# Mezclamos aleatoriamente las combinaciones
random.shuffle(combinaciones)

# Seleccionamos las primeras 1000 combinaciones únicas
nombres_completos = set()
nombres_finales = []
for nombre, apellido1, apellido2 in combinaciones:
    nombre_completo = f"{nombre} {apellido1} {apellido2}"
    if nombre_completo not in nombres_completos:
        nombres_completos.add(nombre_completo)
        nombres_finales.append(nombre_completo)
    if len(nombres_finales) == 1000:
        break

end_time = time.time()
registrar_evento(f" Creacion de las primeras 1000 combinaciones únicas:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1


# REPARTICIÓN DE LOS ESTUDIANTES POR SEMESTRE

import random

# Lista de 1000 nombres generados
# La lista ya está generada como nombres_finales
# nombres_finales = [...]

# Proporciones por semestre
start_time = time.time()
semestre_proporciones = [0.14, 0.13, 0.12, 0.11, 0.10, 0.10, 0.09, 0.08, 0.07, 0.06]

# Calculamos el número de estudiantes por semestre
semestre_cupos = [int(1000 * p) for p in semestre_proporciones]

# Asignamos estudiantes a semestres
estudiantes_por_semestre = {i + 1: [] for i in range(10)}

random.shuffle(nombres_finales)

indice = 0
for semestre, cupo in enumerate(semestre_cupos, start=1):
    for _ in range(cupo):
        estudiante = {
            'nombre': nombres_finales[indice],
            'semestre': semestre
        }
        estudiantes_por_semestre[semestre].append(estudiante)
        indice += 1

end_time = time.time()
registrar_evento(f"Asignacion de los estudiantes a semestres:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1




# CREACIÓN DE LOS DATOS PERSONALES DE LOS ESTUDIANTES
start_time = time.time()
import random
import string

# Proporciones por semestre
semestre_proporciones = [0.14, 0.13, 0.12, 0.11, 0.10, 0.10, 0.09, 0.08, 0.07, 0.06]

# Calculamos el número de estudiantes por semestre
semestre_cupos = [int(1000 * p) for p in semestre_proporciones]

# Asignamos estudiantes a semestres
estudiantes_por_semestre = {i + 1: [] for i in range(10)}

random.shuffle(nombres_finales)

# Función para generar un documento de identidad único
def generar_documento():
    return ''.join(random.choices(string.digits, k=10))

# Función para generar un correo electrónico único
def generar_correo(nombre, indice):
    base_correo = nombre.lower().replace(' ', '.') + f"{indice:04d}"
    return base_correo + "@udea.edu.co"

# Seccionales disponibles
seccionales = [
    "Seccional Urabá", "Sede Norte", "Ciudad Universitaria", "Seccional Occidente",
    "Seccional Suroeste", "Seccional Bajo Cauca", "Sede Distrito Minero",
    "Sede Nordeste", "Seccional Magdalena Medio", "Seccional Oriente", "Sede Sonsón"
]

# Conjuntos para verificar unicidad
documentos_unicos = set()
correos_unicos = set()

indice = 0
for semestre, cupo in enumerate(semestre_cupos, start=1):
    for _ in range(cupo):
        nombre = nombres_finales[indice]
        documento = generar_documento()
        while documento in documentos_unicos:
            documento = generar_documento()
        documentos_unicos.add(documento)

        correo = generar_correo(nombre, indice)
        while correo in correos_unicos:
            correo = generar_correo(nombre, indice + random.randint(1, 1000))
        correos_unicos.add(correo)

        seccional = random.choice(seccionales)

        estudiante = {
            'nombre': nombre,
            'semestre': semestre,
            'documento': documento,
            'correo': correo,
            'seccional': seccional
        }
        estudiantes_por_semestre[semestre].append(estudiante)
        indice += 1

end_time = time.time()
registrar_evento(f"Creacion de los datos personales de los estudiantes:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1

# Imprimimos los primeros 10 estudiantes de cada semestre como ejemplo
for semestre, estudiantes in estudiantes_por_semestre.items():
    print(f"Semestre {semestre}:")
    for estudiante in estudiantes[:10]:
        print(estudiante)


# CREACIÓN DEL ARCHIVO PLANO CON EL LISTADO DE ESTUDIANTES, SEMESTRES Y SUS DATOS PERSONALES

import csv

# Función para escribir los datos de los estudiantes en un archivo CSV
start_time = time.time()
def escribir_estudiantes_csv(estudiantes_por_semestre, filename):
    with open(filename, 'w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=['nombre', 'semestre', 'documento', 'correo', 'seccional'])
        writer.writeheader()
        for semestre, estudiantes in estudiantes_por_semestre.items():
            for estudiante in estudiantes:
                writer.writerow(estudiante)

# Llamada a la función para escribir los datos en un archivo CSV
escribir_estudiantes_csv(estudiantes_por_semestre, 'estudiantes.csv')

end_time = time.time()
registrar_evento(f"Creacion del archivo plano con los datos de los estudiantes:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1
# Out:
# Semestre 1:
# {'nombre': ' Alexander  Pérez  Medina', 'semestre': 1, 'documento': '1302462860', 'correo': '.alexander..pérez..medina0000@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Juan Pablo  Casado  Bravo', 'semestre': 1, 'documento': '9190554109', 'correo': '.juan.pablo..casado..bravo0001@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Catalina  Varela  Medina', 'semestre': 1, 'documento': '4333507425', 'correo': '.catalina..varela..medina0002@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Camila  Romero  Vázquez', 'semestre': 1, 'documento': '6207531476', 'correo': '.camila..romero..vázquez0003@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Andrés  Ortiz  Moya', 'semestre': 1, 'documento': '7139654234', 'correo': '.andrés..ortiz..moya0004@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Santiago  Abad  Serrano', 'semestre': 1, 'documento': '6805973197', 'correo': '.santiago..abad..serrano0005@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Antonella  Moya  Domínguez', 'semestre': 1, 'documento': '7248185368', 'correo': '.antonella..moya..domínguez0006@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Luciana  Robles  López', 'semestre': 1, 'documento': '2908746354', 'correo': '.luciana..robles..lópez0007@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Javier  Mesa  Gómez', 'semestre': 1, 'documento': '0440864996', 'correo': '.javier..mesa..gómez0008@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Valentina  Molina  Fernández', 'semestre': 1, 'documento': '2247222778', 'correo': '.valentina..molina..fernández0009@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# Semestre 2:
# {'nombre': ' Agustín  Llorente  Cabrera', 'semestre': 2, 'documento': '7051252827', 'correo': '.agustín..llorente..cabrera0140@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Samantha  Gallego  Correa', 'semestre': 2, 'documento': '6266686787', 'correo': '.samantha..gallego..correa0141@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Sofía  Sánchez  Luque', 'semestre': 2, 'documento': '2682240788', 'correo': '.sofía..sánchez..luque0142@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Lucas  Lucas  Pastor', 'semestre': 2, 'documento': '4066309814', 'correo': '.lucas..lucas..pastor0143@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Alejandro  Vargas  Aguilar', 'semestre': 2, 'documento': '5872465075', 'correo': '.alejandro..vargas..aguilar0144@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Juan  Serrano  Medina', 'semestre': 2, 'documento': '5842665286', 'correo': '.juan..serrano..medina0145@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Andrés  Calvo  Carmona', 'semestre': 2, 'documento': '3264791066', 'correo': '.andrés..calvo..carmona0146@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Laura  Sánchez  Arias', 'semestre': 2, 'documento': '7196054797', 'correo': '.laura..sánchez..arias0147@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Eduardo  Garrido  Cabrera', 'semestre': 2, 'documento': '2843487954', 'correo': '.eduardo..garrido..cabrera0148@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Samuel  Alonso  Soto', 'semestre': 2, 'documento': '0694922898', 'correo': '.samuel..alonso..soto0149@udea.edu.co', 'seccional': 'Sede Sonsón'}
# Semestre 3:
# {'nombre': ' Natalia  Calvo  Suárez', 'semestre': 3, 'documento': '2041786179', 'correo': '.natalia..calvo..suárez0270@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Pablo  Iglesias  Rodríguez', 'semestre': 3, 'documento': '1503198480', 'correo': '.pablo..iglesias..rodríguez0271@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Ricardo  Marín  Herrero', 'semestre': 3, 'documento': '3253562217', 'correo': '.ricardo..marín..herrero0272@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Carolina  Moreno  Bravo', 'semestre': 3, 'documento': '7362175456', 'correo': '.carolina..moreno..bravo0273@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Daniela  Molina  Vega', 'semestre': 3, 'documento': '1550637049', 'correo': '.daniela..molina..vega0274@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Isabel  Díaz  Serrano', 'semestre': 3, 'documento': '4510609985', 'correo': '.isabel..díaz..serrano0275@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Daniela  Amaya  Peralta', 'semestre': 3, 'documento': '8108321957', 'correo': '.daniela..amaya..peralta0276@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Emma  Herrera  Peralta', 'semestre': 3, 'documento': '4336220901', 'correo': '.emma..herrera..peralta0277@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Alexander  Navarro  Luque', 'semestre': 3, 'documento': '3542947422', 'correo': '.alexander..navarro..luque0278@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Catalina  Santana  Llorente', 'semestre': 3, 'documento': '0039399952', 'correo': '.catalina..santana..llorente0279@udea.edu.co', 'seccional': 'Sede Norte'}
# Semestre 4:
# {'nombre': ' Martín  Ruiz  Molina', 'semestre': 4, 'documento': '5494322399', 'correo': '.martín..ruiz..molina0390@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Leonardo  Moya \ufeffApellidos', 'semestre': 4, 'documento': '1294669733', 'correo': '.leonardo..moya.\ufeffapellidos0391@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Mateo  Ferrer  Fernández', 'semestre': 4, 'documento': '6039025029', 'correo': '.mateo..ferrer..fernández0392@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Pablo  Marín  Suárez', 'semestre': 4, 'documento': '9726488270', 'correo': '.pablo..marín..suárez0393@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Mauricio  Esteban  Miranda', 'semestre': 4, 'documento': '6151064642', 'correo': '.mauricio..esteban..miranda0394@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Daniela  Cruz  Carretero', 'semestre': 4, 'documento': '8433768331', 'correo': '.daniela..cruz..carretero0395@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Antonia  León  Ferrer', 'semestre': 4, 'documento': '9215202719', 'correo': '.antonia..león..ferrer0396@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Juan José  Nieto  Abad', 'semestre': 4, 'documento': '3136132034', 'correo': '.juan.josé..nieto..abad0397@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Andrés  Blanco  Guerrero', 'semestre': 4, 'documento': '5810384233', 'correo': '.andrés..blanco..guerrero0398@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Juan Pablo  Rodríguez  Medina', 'semestre': 4, 'documento': '9359160150', 'correo': '.juan.pablo..rodríguez..medina0399@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# Semestre 5:
# {'nombre': ' Agustín  Ríos  Pérez', 'semestre': 5, 'documento': '5039587771', 'correo': '.agustín..ríos..pérez0500@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Daniela  Bravo  Nieto', 'semestre': 5, 'documento': '1368032378', 'correo': '.daniela..bravo..nieto0501@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Valentina  Ríos  García', 'semestre': 5, 'documento': '8501190389', 'correo': '.valentina..ríos..garcía0502@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# {'nombre': ' Clara  Vargas  Molina', 'semestre': 5, 'documento': '4723898500', 'correo': '.clara..vargas..molina0503@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Sara  Marín  López', 'semestre': 5, 'documento': '7449395161', 'correo': '.sara..marín..lópez0504@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Javier  Ferrer  Martínez', 'semestre': 5, 'documento': '4577367314', 'correo': '.javier..ferrer..martínez0505@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Paula  Benítez  Vicente', 'semestre': 5, 'documento': '5837715452', 'correo': '.paula..benítez..vicente0506@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# {'nombre': ' Miguel  Ramírez  Oliva', 'semestre': 5, 'documento': '8716086825', 'correo': '.miguel..ramírez..oliva0507@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Luciana  Suárez  Pastor', 'semestre': 5, 'documento': '3001136407', 'correo': '.luciana..suárez..pastor0508@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Manuel  Molina  Medina', 'semestre': 5, 'documento': '9940221753', 'correo': '.manuel..molina..medina0509@udea.edu.co', 'seccional': 'Sede Norte'}
# Semestre 6:
# {'nombre': ' Martín  Marín  Lucas', 'semestre': 6, 'documento': '2334502900', 'correo': '.martín..marín..lucas0600@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Gabriela  Moya  Lucas', 'semestre': 6, 'documento': '4457185102', 'correo': '.gabriela..moya..lucas0601@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Santiago  Blanco  González', 'semestre': 6, 'documento': '6190927715', 'correo': '.santiago..blanco..gonzález0602@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Simón  Guerrero  Prieto', 'semestre': 6, 'documento': '1807641254', 'correo': '.simón..guerrero..prieto0603@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Daniela  Vidal  Ortiz', 'semestre': 6, 'documento': '3802032923', 'correo': '.daniela..vidal..ortiz0604@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Eduardo  Santana  Cordero', 'semestre': 6, 'documento': '1509586873', 'correo': '.eduardo..santana..cordero0605@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Esteban  Esteban  Vicente', 'semestre': 6, 'documento': '8458198695', 'correo': '.esteban..esteban..vicente0606@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Samantha  Garrido  Domínguez', 'semestre': 6, 'documento': '6657395118', 'correo': '.samantha..garrido..domínguez0607@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Simón  García  Torres', 'semestre': 6, 'documento': '5960217653', 'correo': '.simón..garcía..torres0608@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Alexander  Guerrero  Reyes', 'semestre': 6, 'documento': '5178976007', 'correo': '.alexander..guerrero..reyes0609@udea.edu.co', 'seccional': 'Seccional Oriente'}
# Semestre 7:
# {'nombre': ' Victoria  Aguilar  Santana', 'semestre': 7, 'documento': '2787772014', 'correo': '.victoria..aguilar..santana0700@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' David  Ochoa  Hidalgo', 'semestre': 7, 'documento': '5097263291', 'correo': '.david..ochoa..hidalgo0701@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' María José  Castro  Casado', 'semestre': 7, 'documento': '5281655758', 'correo': '.maría.josé..castro..casado0702@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Emilio  Gil \ufeffApellidos', 'semestre': 7, 'documento': '8229971131', 'correo': '.emilio..gil.\ufeffapellidos0703@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Agustín  Medina  Robles', 'semestre': 7, 'documento': '0395004628', 'correo': '.agustín..medina..robles0704@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Sebastián  Medina  Rubio', 'semestre': 7, 'documento': '3096019104', 'correo': '.sebastián..medina..rubio0705@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Ángel  López  Suárez', 'semestre': 7, 'documento': '0071789876', 'correo': '.ángel..lópez..suárez0706@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Manuel  Ramos  Serrano', 'semestre': 7, 'documento': '5492689945', 'correo': '.manuel..ramos..serrano0707@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Natalia  Suárez  Gallego', 'semestre': 7, 'documento': '0504400107', 'correo': '.natalia..suárez..gallego0708@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Diego  Rubio  Fernández', 'semestre': 7, 'documento': '4077597640', 'correo': '.diego..rubio..fernández0709@udea.edu.co', 'seccional': 'Sede Norte'}
# Semestre 8:
# {'nombre': ' Santiago  Aguilar  León', 'semestre': 8, 'documento': '9842382963', 'correo': '.santiago..aguilar..león0790@udea.edu.co', 'seccional': 'Seccional Urabá'}
# {'nombre': ' Daniel  Ortega  Oliva', 'semestre': 8, 'documento': '9371788320', 'correo': '.daniel..ortega..oliva0791@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Alexander  Serrano  Esteban', 'semestre': 8, 'documento': '5207685743', 'correo': '.alexander..serrano..esteban0792@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Sofia  Blanco  Cabrera', 'semestre': 8, 'documento': '0765174282', 'correo': '.sofia..blanco..cabrera0793@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Mariana  Navarro  Robles', 'semestre': 8, 'documento': '3279971513', 'correo': '.mariana..navarro..robles0794@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Antonia  Molina  González', 'semestre': 8, 'documento': '8535839515', 'correo': '.antonia..molina..gonzález0795@udea.edu.co', 'seccional': 'Ciudad Universitaria'}
# {'nombre': ' Valentina  Gutiérrez  Castro', 'semestre': 8, 'documento': '1865475714', 'correo': '.valentina..gutiérrez..castro0796@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Simón  Gil  Garrido', 'semestre': 8, 'documento': '9974737784', 'correo': '.simón..gil..garrido0797@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Isabella  Bravo  Correa', 'semestre': 8, 'documento': '9916803341', 'correo': '.isabella..bravo..correa0798@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# {'nombre': ' Esteban  Navarro  Soler', 'semestre': 8, 'documento': '2135108795', 'correo': '.esteban..navarro..soler0799@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# Semestre 9:
# {'nombre': ' Sofía  Nieto  Carmona', 'semestre': 9, 'documento': '2772560501', 'correo': '.sofía..nieto..carmona0870@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Gabriela  Romero  Herrero', 'semestre': 9, 'documento': '8653289080', 'correo': '.gabriela..romero..herrero0871@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# {'nombre': ' José  Herrera  Garrido', 'semestre': 9, 'documento': '6166433753', 'correo': '.josé..herrera..garrido0872@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Martín  Cabello  Molina', 'semestre': 9, 'documento': '0033270044', 'correo': '.martín..cabello..molina0873@udea.edu.co', 'seccional': 'Seccional Occidente'}
# {'nombre': ' Laura  Ramos  Vidal', 'semestre': 9, 'documento': '1939333825', 'correo': '.laura..ramos..vidal0874@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Clara  Luque  Ortiz', 'semestre': 9, 'documento': '9526297957', 'correo': '.clara..luque..ortiz0875@udea.edu.co', 'seccional': 'Sede Sonsón'}
# {'nombre': ' Antonia  Ramos  Herrero', 'semestre': 9, 'documento': '9169339724', 'correo': '.antonia..ramos..herrero0876@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' María José  López  Rivas', 'semestre': 9, 'documento': '3258045574', 'correo': '.maría.josé..lópez..rivas0877@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Gabriela  Peralta  Gil', 'semestre': 9, 'documento': '3352589468', 'correo': '.gabriela..peralta..gil0878@udea.edu.co', 'seccional': 'Sede Norte'}
# {'nombre': ' Carolina  Cabrera  Arias', 'semestre': 9, 'documento': '0058161811', 'correo': '.carolina..cabrera..arias0879@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# Semestre 10:
# {'nombre': ' Mariana  Pastor  Miranda', 'semestre': 10, 'documento': '6961693366', 'correo': '.mariana..pastor..miranda0940@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Jimena  Martínez  Cortés', 'semestre': 10, 'documento': '5333071055', 'correo': '.jimena..martínez..cortés0941@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Gabriela  Castro  Moya', 'semestre': 10, 'documento': '8253195491', 'correo': '.gabriela..castro..moya0942@udea.edu.co', 'seccional': 'Seccional Suroeste'}
# {'nombre': ' Cristóbal  Ruiz  Linares', 'semestre': 10, 'documento': '3279495466', 'correo': '.cristóbal..ruiz..linares0943@udea.edu.co', 'seccional': 'Seccional Magdalena Medio'}
# {'nombre': ' Daniela  Prieto  Molina', 'semestre': 10, 'documento': '9287671779', 'correo': '.daniela..prieto..molina0944@udea.edu.co', 'seccional': 'Sede Distrito Minero'}
# {'nombre': ' Sofía  Ramos  Rubio', 'semestre': 10, 'documento': '9103721988', 'correo': '.sofía..ramos..rubio0945@udea.edu.co', 'seccional': 'Sede Nordeste'}
# {'nombre': ' Gabriela  Linares  Cervantes', 'semestre': 10, 'documento': '7725948758', 'correo': '.gabriela..linares..cervantes0946@udea.edu.co', 'seccional': 'Seccional Oriente'}
# {'nombre': ' Valeria  García  Gil', 'semestre': 10, 'documento': '3235279403', 'correo': '.valeria..garcía..gil0947@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Paula  Gil  Suárez', 'semestre': 10, 'documento': '7961965913', 'correo': '.paula..gil..suárez0948@udea.edu.co', 'seccional': 'Seccional Bajo Cauca'}
# {'nombre': ' Natalia  Casado  Vargas', 'semestre': 10, 'documento': '1664417421', 'correo': '.natalia..casado..vargas0949@udea.edu.co', 'seccional': 'Sede Nordeste'}

# %% [markdown]
# ##Creación de las listas

# %%
import os
start_time = time.time()
# Función para crear una carpeta si no existe
def crear_carpeta_si_no_existe(ruta):
    if not os.path.exists(ruta):
        os.makedirs(ruta)

# Crear carpeta "Entrega Final" en el entorno de Colab
entrega_final_path = 'Entrega Final'
crear_carpeta_si_no_existe(entrega_final_path)

end_time = time.time()
registrar_evento(f"Creacion carpeta Entrega Final en el entorno de Colab:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1

# %% [markdown]
# ###Creación de las carpetas de los semestres

# %%
import os
import pandas as pd
from datetime import datetime

# Crear carpeta "Entrega Final"
entrega_final_path = 'Entrega Final'
if not os.path.exists(entrega_final_path):
    os.makedirs(entrega_final_path)

# Materias por semestre
materias_por_semestre = {
    1: [
        {"nombre": "Álgebra y Trigonometría", "creditos": 3},
        {"nombre": "Cálculo Diferencial", "creditos": 3},
        {"nombre": "Geometría Vectorial y Analítica", "creditos": 3},
        {"nombre": "Vivamos la Universidad", "creditos": 3},
        {"nombre": "Inglés I", "creditos": 1},
        {"nombre": "Lectoescritura", "creditos": 1},
        {"nombre": "Introducción a la Ingeniería Industrial", "creditos": 1},
    ],
    2: [
        {"nombre": "Álgebra Lineal", "creditos": 3},
        {"nombre": "Cálculo Integral", "creditos": 3},
        {"nombre": "Descubriendo la Física", "creditos": 3},
        {"nombre": "Gestión de las Organizaciones", "creditos": 3},
        {"nombre": "Inglés II", "creditos": 1},
        {"nombre": "Habilidades Gerenciales", "creditos": 3},
    ],
    3: [
        {"nombre": "Algoritmia y Programación", "creditos": 3},
        {"nombre": "Física Mecánica", "creditos": 3},
        {"nombre": "Gestión Contable", "creditos": 3},
        {"nombre": "Probabilidad e Inferencia Estadística", "creditos": 3},
        {"nombre": "Inglés III", "creditos": 1},
        {"nombre": "Teoría General de Sistemas", "creditos": 3},
    ],
    4: [
        {"nombre": "Diseño de Experimentos y Análisis de Regresión", "creditos": 3},
        {"nombre": "Electiva en Física", "creditos": 3},
        {"nombre": "Gestión de Métodos y Tiempos", "creditos": 4},
        {"nombre": "Ingeniería Económica", "creditos": 3},
        {"nombre": "Inglés IV", "creditos": 1},
        {"nombre": "Optimización", "creditos": 3},
    ],
    5: [
        {"nombre": "Dinámica de Sistemas", "creditos": 3},
        {"nombre": "Formación ciudadana y Constitucional", "creditos": 1},
        {"nombre": "Gestión Financiera", "creditos": 3},
        {"nombre": "Gestión por Procesos", "creditos": 3},
        {"nombre": "Inglés V", "creditos": 1},
        {"nombre": "Laboratorio Integrado de Física", "creditos": 1},
        {"nombre": "Muestreo y Series de Tiempo", "creditos": 3},
        {"nombre": "Procesos Estocásticos y Análisis de Decisión", "creditos": 3},
    ],
    6: [
        {"nombre": "Electiva en Humanidades I", "creditos": 3},
        {"nombre": "Formulación de Proyectos de Investigación", "creditos": 3},
        {"nombre": "Gestión Tecnológica", "creditos": 3},
        {"nombre": "Inglés VI", "creditos": 1},
        {"nombre": "Legislación", "creditos": 3},
        {"nombre": "Normalización y Control de la Calidad", "creditos": 3},
        {"nombre": "Simulación Discreta", "creditos": 3},
    ],
    7: [
        {"nombre": "Diseño de Sistemas Productivos", "creditos": 3},
        {"nombre": "Electiva Complementaria I", "creditos": 3},
        {"nombre": "Electiva en Humanidades II", "creditos": 3},
        {"nombre": "Emprendimiento", "creditos": 2},
        {"nombre": "Énfasis Profesional I", "creditos": 3},
        {"nombre": "Formulación y Evaluación de Proyectos de Inversión", "creditos": 3},
    ],
    8: [
        {"nombre": "Administración de la Producción y del Servicio", "creditos": 3},
        {"nombre": "Electiva Complementaria II", "creditos": 3},
        {"nombre": "Electiva en Humanidades III", "creditos": 3},
        {"nombre": "Énfasis Profesional II", "creditos": 3},
        {"nombre": "Gestión de Proyectos", "creditos": 3},
    ],
    9: [
        {"nombre": "Electiva Complementaria III", "creditos": 3},
        {"nombre": "Electiva en Humanidades IV", "creditos": 3},
        {"nombre": "Gestión de la Cadena de Abastecimiento", "creditos": 3},
        {"nombre": "Énfasis Profesional III", "creditos": 3},
        {"nombre": "Ingeniería del Mejoramiento Continuo", "creditos": 3},
    ],
    10: [
        {"nombre": "Práctica Profesional", "creditos": 12},
    ],
}

# Reglas de conversión de créditos a HTD y HTI
creditos_a_htd = {
    12: 288,
    4: 96,
    3: 64,
    2: 32,
    1: 16
}
creditos_a_hti = {
    12: 360,
    4: 120,
    3: 80,
    2: 64,
    1: 32
}

# Capacidad máxima de los grupos por semestre
capacidad_grupos = {
    1: 30,
    2: 30,
    3: 30,
    4: 25,
    5: 25,
    6: 25,
    7: 20,
    8: 20,
    9: 20,
    10: 10
}

# Función para generar un código de asignatura
start_time = time.time()
def generar_codigo_asignatura(nombre, semestre, creditos, consecutivo):
    nombre_reducido = ''.join([palabra[0] for palabra in nombre.split()][:3])
    nombre_reducido = (nombre_reducido + nombre[:3]).upper()[:3]
    codigo = f"{nombre_reducido}{semestre}{creditos}{consecutivo}"
    return codigo

end_time = time.time()
registrar_evento(f"generacion de un código de asignatura:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1

# Leer datos de estudiantes desde el archivo estudiantes.csv
estudiantes_df = pd.read_csv('estudiantes.csv')

# Crear carpetas de semestre del 1 al 10
start_time = time.time()
for semestre in range(1, 11):
    semestre_path = os.path.join(entrega_final_path, f'semestre {semestre}')
    if not os.path.exists(semestre_path):
        os.makedirs(semestre_path)

    if semestre in materias_por_semestre:
        materias_semestre = materias_por_semestre[semestre]
        codigos_asignaturas_semestre = {}
        consecutivos = {}
        asignaturas_info = []

        for asignatura in materias_semestre:
            nombre = asignatura["nombre"]
            creditos = asignatura["creditos"]
            htd = creditos_a_htd[creditos]
            hti = creditos_a_hti[creditos]

            if nombre not in consecutivos:
                consecutivos[nombre] = 1
            else:
                consecutivos[nombre] += 1

            codigo = generar_codigo_asignatura(nombre, semestre, creditos, consecutivos[nombre])
            codigos_asignaturas_semestre[nombre] = codigo

            asignaturas_info.append({
                "nombre": nombre,
                "codigo": codigo,
                "creditos": creditos,
                "htd": htd,
                "hti": hti
            })

end_time = time.time()
registrar_evento(f"Calculo de las Horas de Trabajo Docente (HTD):  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1
registrar_evento(f"Calculo de las Horas de Trabajo Independiente (HTI):  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1
registrar_evento(f"Creacion de carpetas de semestre del 1 al 10:  en {end_time - start_time:.3f} segundos")
cantidad_procedimientos += 1

        # Seleccionar estudiantes para el semestre actual
estudiantes_semestre = estudiantes_df[estudiantes_df['semestre'] == semestre]
estudiantes_semestre = estudiantes_semestre.sample(frac=1).reset_index(drop=True)  # Mezclar estudiantes

        # Crear carpetas de asignaturas y archivos dentro de cada semestre
for asignatura in asignaturas_info:
    asignatura_path = os.path.join(semestre_path, asignatura["nombre"].replace(" ", "_"))
if not os.path.exists(asignatura_path):
    os.makedirs(asignatura_path)

            # Dividir estudiantes en grupos según la capacidad máxima del semestre
capacidad = capacidad_grupos[semestre]
grupos = [estudiantes_semestre[i:i + capacidad] for i in range(0, len(estudiantes_semestre), capacidad)]

for idx, grupo in enumerate(grupos):
    cantidad_estudiantes = len(grupo)
    codigo_grupo = idx + 1
    nombre_archivo = f"{asignatura['codigo']}-{asignatura['nombre'].replace(' ', '')}-{cantidad_estudiantes}-G{codigo_grupo}"

    df = grupo.copy()
    df['Código Asignatura'] = asignatura['codigo']
    df['Horas de trabajo docente (HTD)'] = asignatura['htd']
    df['Horas de trabajo independiente (HTI)'] = asignatura['hti']
    df['Número total de estudiantes (NTE)'] = cantidad_estudiantes
    df['Código del curso (CC)'] = f"{asignatura['codigo']}-G{codigo_grupo}"
    df['Total de cursos asignados (TCA)'] = len(grupos)
    df['Fecha de creación (FC)'] = datetime.now().strftime("%Y/%m/%d")
    df['Créditos de la asignatura'] = asignatura['creditos']

    ruta_excel = os.path.join(asignatura_path, f"{nombre_archivo}.xlsx")
    start_time = time.time()
    with pd.ExcelWriter(ruta_excel) as writer:
         df.to_excel(writer, sheet_name="Estudiantes", index=False)
    end_time = time.time()
    registrar_evento(f"Guardado archivo Excel:  en {end_time - start_time:.3f} segundos")
    cantidad_procedimientos += 1

    ruta_csv = os.path.join(asignatura_path, f"{nombre_archivo}.csv")
    start_time = time.time()
    df.to_csv(ruta_csv, index=False)
    end_time = time.time()
    registrar_evento(f"Guardado archivo CSV:  en {end_time - start_time:.3f} segundos")
    cantidad_procedimientos += 1

        # Registrar la cantidad total de procedimientos realizados
registrar_evento(f"Cantidad total de procedimientos realizados: {cantidad_procedimientos}")

print("Operaciones realizadas y eventos registrados exitosamente.")

print(f"Archivos de planeación para el semestre {semestre} creados exitosamente.")
# Out:
# Operaciones realizadas y eventos registrados exitosamente.
# Archivos de planeación para el semestre 10 creados exitosamente.
